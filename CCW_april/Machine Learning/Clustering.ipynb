# %% [markdown]
# # Clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt
import numpy as np

# %%
# 创建一些随机数据
X = np.random.rand(100, 2)

# 定义聚类数目
k = 3

# 使用K-Means算法进行聚类
kmeans = KMeans(n_clusters=k)
kmeans.fit(X)

# 获取聚类结果
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
centroids
# Out:
# array([[0.41830692, 0.80227666],
#        [0.75338603, 0.30333254],
#        [0.19138481, 0.20055938]])

# %%
# 使用层次聚类算法
Z = linkage(X, method='single')  # 单链接聚类方法

# 绘制谱系图
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.show()

# %%
# 使用DBSCAN算法进行聚类
dbscan = DBSCAN(eps=0.1, min_samples=5)
dbscan.fit(X)

# 获取聚类结果
labels = dbscan.labels_
labels
# Out:
# array([ 0, -1,  0, -1, -1, -1, -1, -1, -1,  4,  1,  6,  2,  3,  3, -1,  0,
#        -1,  0,  0,  3,  1,  3,  2, -1,  4, -1, -1,  1,  0,  5,  4,  1,  5,
#         2,  6, -1, -1,  5,  7, -1, -1,  3,  5,  0,  4, -1, -1,  4, -1,  6,
#         0,  1, -1, -1,  4, -1,  2,  3,  7, -1,  1,  3, -1,  7,  2,  1,  1,
#        -1,  5,  3,  0,  0,  3, -1, -1, -1, -1,  0,  0, -1,  7,  5, -1,  1,
#        -1,  1, -1, -1, -1,  0, -1, -1,  7, -1,  4,  1,  6,  1,  6],
#       dtype=int64)

# %%
# 创建一些随机数据
X = np.random.rand(100, 2)

# 使用GMM算法进行聚类
gmm = GaussianMixture(n_components=3)
gmm.fit(X)

# 获取聚类结果
labels = gmm.predict(X)
labels
# Out:
# array([0, 1, 0, 1, 0, 0, 2, 2, 1, 0, 0, 1, 1, 0, 1, 1, 2, 0, 1, 1, 1, 0,
#        2, 2, 0, 1, 2, 0, 0, 1, 0, 0, 0, 2, 0, 2, 1, 0, 0, 1, 1, 1, 0, 0,
#        1, 0, 1, 2, 1, 1, 1, 1, 1, 0, 0, 1, 0, 1, 2, 1, 1, 2, 2, 0, 0, 2,
#        0, 1, 2, 2, 1, 1, 1, 1, 0, 1, 1, 0, 2, 1, 0, 2, 1, 1, 1, 1, 1, 1,
#        0, 0, 1, 2, 2, 1, 0, 1, 0, 2, 0, 1], dtype=int64)
